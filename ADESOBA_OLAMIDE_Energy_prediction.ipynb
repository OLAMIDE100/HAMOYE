# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from ipywidgets import widgets
import seaborn as sn
from ipywidgets import widgets
from matplotlib import pyplot
import matplotlib.patches as mpatches
pd.set_option('max_columns', None)

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
import sklearn.metrics as metrics

# %%
train = pd.read_csv(r'C:\Users\ADESOBA OLAMIDE\Desktop\HAMOYE\STAGE 2\energydata_complete.csv')

# %%
train.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4       RH_4         T5   RH_5        T6  \
# 0  19.79  44.730000  19.000000  45.566667  17.166667  55.20  7.026667
# 1  19.79  44.790000  19.000000  45.992500  17.166667  55.20  6.833333
# 2  19.79  44.933333  18.926667  45.890000  17.166667  55.09  6.560000
# 3  19.79  45.000000  18.890000  45.723333  17.166667  55.09  6.433333
# 4  19.79  45.000000  18.890000  45.530000  17.200000  55.09  6.366667
#
#         RH_6         T7       RH_7    T8       RH_8         T9   RH_9  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
train.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
train.shape
# Out:
# (19735, 29)

# %%
train = train.drop(["date","lights"],axis=1)

# %%
train.isna().sum()
# Out:
# Appliances     0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
corr = train.corr()
corr
# Out:
#              Appliances        T1      RH_1        T2      RH_2        T3  \
# Appliances     1.000000  0.055447  0.086031  0.120073 -0.060465  0.085060
# T1             0.055447  1.000000  0.164006  0.836834 -0.002509  0.892402
# RH_1           0.086031  0.164006  1.000000  0.269839  0.797535  0.253230
# T2             0.120073  0.836834  0.269839  1.000000 -0.165610  0.735245
# RH_2          -0.060465 -0.002509  0.797535 -0.165610  1.000000  0.137319
# T3             0.085060  0.892402  0.253230  0.735245  0.137319  1.000000
# RH_3           0.036292 -0.028550  0.844677  0.121497  0.678326 -0.011234
# T4             0.040281  0.877001  0.106180  0.762066 -0.047304  0.852778
# RH_4           0.016965  0.097861  0.880359  0.231563  0.721435  0.122737
# T5             0.019760  0.885247  0.205797  0.720550  0.110409  0.888169
# RH_5           0.006955 -0.014782  0.303258  0.029595  0.250271 -0.066355
# T6             0.117638  0.654769  0.316141  0.801186 -0.009670  0.686882
# ...

# %%
highest_corr_features = corr.index[abs(corr["Appliances"])>0.0]
plt.figure(figsize=(10,10))
g = sn.heatmap(train[highest_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
pd.DataFrame(abs(corr["Appliances"])).sort_values(by='Appliances', ascending=False)
# Out:
#              Appliances
# Appliances     1.000000
# RH_out         0.152282
# T2             0.120073
# T6             0.117638
# T_out          0.099155
# RH_8           0.094039
# Windspeed      0.087122
# RH_1           0.086031
# T3             0.085060
# RH_6           0.083178
# RH_2           0.060465
# RH_7           0.055642
# T1             0.055447
# RH_9           0.051462
# T4             0.040281
# T8             0.039572
# RH_3           0.036292
# Press_mm_hg    0.034885
# T7             0.025801
# T5             0.019760
# RH_4           0.016965
# Tdewpoint      0.015353
# rv1            0.011145
# rv2            0.011145
# T9             0.010010
# RH_5           0.006955
# Visibility     0.000230

# %%
def features_plot(df,target):
    features = [c for c in df.columns if (df[c].dtype == 'float64' or df[c].dtype == 'int64') and c != target]
    
    if df[target].dtype != 'float64' and df[target].dtype != 'int64':
        return 'error: target not a continous value'
    
    def plot_feature(column):
        plt.plot(df[column], df[target], '.')
        plt.xlabel(column)
        plt.ylabel('target')

    dropdown_menu = [k for k in features]

    return widgets.interact(plot_feature, column=dropdown_menu);

# %%
features_plot(train,'Appliances')
# Out:
# interactive(children=(Dropdown(description='column', options=('T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', …
# <function __main__.features_plot.<locals>.plot_feature(column)>

# %%
def features_his(df):
    features = [c for c in df.columns if (df[c].dtype == 'float64' or df[c].dtype == 'int64')]
    
    
    def plot_feature(column):
        sn.histplot(x=df[column])

    dropdown_menu = [k for k in features]

    return widgets.interact(plot_feature, column=dropdown_menu);

# %%
features_his(train)
# Out:
# interactive(children=(Dropdown(description='column', options=('Appliances', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', …
# <function __main__.features_his.<locals>.plot_feature(column)>

# %% [markdown]
# feature = train.drop(["Appliances"],axis = 1)
# target = train["Appliances"]

# %%
feature = train["T2"].values.reshape(-1,1)
target = train["T6"]

# %%
X_train, X_test, y_train, y_true = train_test_split(feature,target, test_size=0.3,random_state=42)

# %%
pipe = Pipeline([('scaler',MinMaxScaler() ),
                      ('regressor', LinearRegression())])
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('regressor', LinearRegression())])

# %%
pipe = Pipeline([("std_scaler", MinMaxScaler()),("lasso_reg", Lasso(alpha=0.001))])
pipe.fit(X_train,y_train)

# %%
pipe = Pipeline([("std_scaler",MinMaxScaler()),("poly_reg", PolynomialFeatures(degree = 3)),('regressor', LinearRegression())])
pipe.fit(X_train,y_train)

# %%
y_pred = pipe.predict(X_test)

# %%
coef_table = pd.DataFrame(list(X_train.columns)).copy()
coef_table["coef"] = pipe['regressor'].coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-b5e1a25bcd8c> in <module>
# ----> 1 coef_table = pd.DataFrame(list(X_train.columns)).copy()
#       2 coef_table["coef"] = pipe['regressor'].coef_
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
coef_table.sort_values(by="coef")

# %%
explained_variance=metrics.explained_variance_score(y_true, y_pred)
mean_absolute_error=metrics.mean_absolute_error(y_true, y_pred) 
mse=metrics.mean_squared_error(y_true, y_pred) 
median_absolute_error=metrics.median_absolute_error(y_true, y_pred)
r2=metrics.r2_score(y_true, y_pred)

print('explained_variance: ', round(explained_variance,4))    
print('r2: ', round(r2,4))
print('MAE: ', round(mean_absolute_error,4))
print('MSE: ', round(mse,4))
print('RMSE: ', round(np.sqrt(mse),4))
# Out:
# explained_variance:  0.6428
# r2:  0.6428
# MAE:  2.8229
# MSE:  13.1792
# RMSE:  3.6303

# %%
rss = np.sum(np.square(y_true - y_pred))
rss
# Out:
# 78033.97179739829
